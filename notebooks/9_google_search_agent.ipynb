# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import GoogleSerperAPIWrapper
from langchain_groq import ChatGroq
from langchain.agents import create_agent

# %%
model = ChatGroq(model = "openai/gpt-oss-20b")
search = GoogleSerperAPIWrapper()

# %%
agent = create_agent(
    model = model,
    tools = [
        search.run
    ],
    system_prompt = "You are a agent and can search for any question on google."

)

# %%
question = "Who won the women's world cup 2025"

# %%
response = agent.invoke({"messages": [{"role": "user", "content": question}]})

# %%
print(response['messages'][-1].content)
# Out:
# There has not been a FIFA Women’s World Cup in 2025. The tournament is held every four years, with the most recent edition in 2023 (won by Spain) and the next scheduled for 2027. Therefore, there is no winner for a 2025 Women’s World Cup.
