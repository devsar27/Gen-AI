# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model = "gemma3:1b")

# %%
res = llm.invoke("Hello, I am Dev")
res.content
# Out:
# 'Hi Dev! It’s nice to hear from you.  How can I help today? Do you have any questions for me or would you like to chat about anything in particular – maybe a coding problem or just general discussion? 😊  🎉'
