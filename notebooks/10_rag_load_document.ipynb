# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ##Text Document Loader

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader(
    "../data/speech.txt",
    encoding="utf-8"
)
texts = loader.load()
len(texts)

oneDoc = texts[0]
print(oneDoc.page_content)
# Out:
# “My dear friends, students, and respected farmers,
#
# Today, I want to speak from the heart about three pillars that define the future of our nation:
# our youth, our education system, and our farmers.
#
# 🎓 For the Youth
#
# You are the energy that drives our state forward.
# Our commitment is to give you:
# 	•	Skill-based education
# 	•	Digital learning opportunities
# 	•	Better employment pathways
# 	•	Support for innovation, startups, and entrepreneurship
#
# Your dreams are not just your own—they are the dreams of our entire society.
#
# 📚 For Education
#
# Education must not be just a formality; it must be a force of transformation.
# We aim to:
# 	•	Upgrade government schools with smart classrooms
# 	•	Improve teacher training
# 	•	Expand scholarships for higher education
# 	•	Promote technical and vocational courses
# 	•	Ensure every child gets a fair opportunity to learn and grow
#
# Education is the foundation on which we will build tomorrow.
#
# 👨‍🌾 For Farmers
#
# Our farmers are our pride.
# We honor their hard work and promise them:
# 	•	Better irrigation systems
# 	•	Access to modern farming technology
# 	•	Fair and timely MSP
# 	•	Improved cold storage and transport facilities
# 	•	Easier access to credit and crop insurance
#
# A nation that respects its farmers grows stronger every day.
#
# Friends,
# If we empower our youth, strengthen our education system, and support our farmers, no force can stop us from achieving prosperity.
#
# Let us walk this path together—towards growth, stability, and a brighter future.
#
# Thank you. Jai Hind.”

# %% [markdown]
# ##PDF Document Loader

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("../data/medical_report.pdf")
docs = loader.load()
len(docs)
# Out:
# 9

# %%
oneDoc = docs[0]
print(oneDoc.page_content)
# Out:
# Report Status
# Female
# 27 Years:
# :
# :
# :
# Age
# Gender
# Reported
# P
# 9/7/2025   4:56:00PM
# DR NITIN NAHAR
# 474764803
# Ms. NIKITA  CHUDHARY:
# :
# :
# :
# :
# Name
# Lab No.
# Ref By
# Collected
# A/c Status
# 10/7/2025  6:31:50PM
# Final
# Collected at            : Processed at             :BHOPAL CC-82
# Mr Rachel V John Pata So Vitus John Mig 26
# Graund,Indrapuri, Phone: 8770817968
#
# LPL - Bhopal Lab II
# Plot No.05, Mandakini Housing Society, Near
# Apurti Shopping Mall, Kolar Main Road,
# Bhopal, M.P. -  462042
# Test Report
# Test Name Results Units Bio. Ref. Interval
# HEMOGRAM
# (SLS Method, Sheath Flow DC Detection Method, Fluorescent Flow Cytometry, Calculated & Capillary Photometry)
# Hemoglobin  12.00 - 15.00 g/dL13.10
# Packed Cell Volume (PCV)  36.00 - 46.00 %39.50
# RBC Count  3.80 - 4.80 mill/mm34.47
# MCV  83.00 - 101.00 fL88.40
# Mentzer Index   19.8
# MCH  27.00 - 32.00 pg29.30
# MCHC  31.50 - 34.50 g/dL33.20
# Red Cell Distribution Width (RDW)  11.60 - 14.00 %11.90
# Total Leukocyte Count (TLC)  4.00 - 10.00 thou/mm37.33
# Differential Leucocyte Count (DLC)
#  40.00 - 80.00 Segmented Neutrophils %49.10
#  20.00 - 40.00 Lymphocytes %41.90
#  2.00 - 10.00 Monocytes %6.00
#  1.00 - 6.00 Eosinophils %2.50
#  <2.00 Basophils %0.50
# Absolute Leucocyte Count
#  2.00 - 7.00 Neutrophils thou/mm33.60
#  1.00 - 3.00 Lymphocytes thou/mm33.07
#  0.20 - 1.00 Monocytes thou/mm30.44
#  0.02 - 0.50 Eosinophils thou/mm30.18
# *474764803*
# .
# Page 1 of 9

# %% [markdown]
# ##CSV File loader

# %%
from langchain_community.document_loaders import CSVLoader
loader = CSVLoader("../data/employee_records.csv")
csvv1 = loader.load()
len(csvv1)
csvv1[:5]
# Out:
# [Document(metadata={'source': '../data/employee_records.csv', 'row': 0}, page_content='Employee_ID: 1\nEmployee_Name: Daniel Taylor\nAge: 25\nCountry: UK\nDepartment: HR\nPosition: Analyst\nSalary: 142278.32\nJoining_Date: 2023-06-04'),
#  Document(metadata={'source': '../data/employee_records.csv', 'row': 1}, page_content='Employee_ID: 2\nEmployee_Name: Ethan Brown\nAge: 44\nCountry: India\nDepartment: Marketing\nPosition: Executive\nSalary: 98549.2\nJoining_Date: 2018-01-13'),
#  Document(metadata={'source': '../data/employee_records.csv', 'row': 2}, page_content='Employee_ID: 3\nEmployee_Name: Sophia Martinez\nAge: 51\nCountry: Japan\nDepartment: Finance\nPosition: Developer\nSalary: 85565.84\nJoining_Date: 2015-04-30'),
#  Document(metadata={'source': '../data/employee_records.csv', 'row': 3}, page_content='Employee_ID: 4\nEmployee_Name: Ethan Martinez\nAge: 47\nCountry: Germany\nDepartment: Support\nPosition: Analyst\nSalary: 34513.67\nJoining_Date: 2015-06-17'),
#  Document(metadata={'source': '../data/employee_records.csv', 'row': 4}, page_content='Employee_ID: 5\nEmployee_Name: Mia Brown\nAge: 32\nCountry: Australia\nDepartment: Support\nPosition: Consultant\nSalary: 45339.72\nJoining_Date: 2019-02-22')]

# %% [markdown]
# ##WebPage Loader

# %%
from langchain_community.document_loaders import WebBaseLoader
loader = WebBaseLoader(web_path = "https://vector.techsimplus.com/")
docs = loader.load()

# %%
docs[0].page_content
# Out:
# "Gen-AI Developer Course 2026 | LangGraph · MCP · RAG | TechSimPlusInitializing Vector 1.000%TechSimPlusLearningsCurriculumProjectsPricingFAQLoginEnroll NowCurriculumProjectsPricingFAQEnroll — ₹21,000LoginProduction RAGLangGraphMCPAWS BedrockAgenticPineconeAnthropicVector 1.0 · Starts 18 Jun 2026Crack senior Gen-AI Developer interviewsEven with Zero Gen-AI Experience.Sixty days. Five production projects. Five mock interviews. Built and taught by a Sr. Gen-AI Developer.Enroll — ₹21,000Free interview PDFStarts 18 Jun 2026·Vector 1.0 · capped at 150 engineers·Registration closes on 13 Jun 2026What you walk away withSixty days, four hard outcomes.0ProjectsProduction-grade, deployed, code-reviewed0Interviews1:1 mocks with written feedback0QuestionsDrilled across Product design + Gen-AI depth0DaysLive program with hard deadlinesSwipe for moreWhy this is differentWhat Sets Vector 1.0 Apart From Other Gen-AI CoursesVector 1.0Gen-AI Developer SprintLive program with hard project deadlines5 production-deployed projects, code-reviewedStack: LangGraph · MCP · Agentic RAG · AWS Bedrock1:1 mock interviews with written feedbackArchitecture decision records you can defendTaught by a Sr. Gen-AI Developer who buildsCapped at 150 — every capstone reviewed personallyOther coursesGeneric Gen-AI coursesPre-recorded videos, no deadlinesToy notebooks that never see productionOnly LangChain basics, RAG pseudocodeNo mock interviews, generic worksheetsNo defendable system design discussionTaught by full-time creators, not practitionersThousands of students, zero personal reviewSwipe for moreHow it worksThree things. That change everything.A practitioner-led path with real builds and real interviews — designed so by day 60 your GitHub, resume and confidence are all interview-ready.01A developer teaches youNot a course creator. A Sr. Gen-AI Developer who ships these systems in production every day.Live classReal practitionerCode reviews02You build five real projectsNot toy demos. Deployable Gen-AI systems on your GitHub by day 60 — each one defendable in any interview.GitHub-deployableProduction patternsDefendable03You rehearse five interviewsReal questions. Real feedback. Real readiness. Your actual interview becomes the sixth one, not the first.1:1 mocksWritten feedback5 roundsSwipe for moreBuild it. Defend it. Get hired. 60 days.The stackTools that show up in real 2026 Gen-AI job descriptions.All taught hands-on with production patterns — never as toy notebooks.15 tools · 4 layersAllFrameworksModels & MCPVector + RAGCloud & DeployLangChainAgent frameworkFrameworksLangGraphStateful agentsFrameworksPydanticData validationFrameworksOpenAIGPT modelsModels & MCPAnthropicClaude modelsModels & MCPMCPTool protocolModels & MCPHuggingFaceOpen modelsModels & MCPPineconeVector DBVector + RAGQdrantVector DBVector + RAGWeaviateVector DBVector + RAGRAGASRAG evalsVector + RAGAWS BedrockInference cloudCloud & DeployFastAPIPython APICloud & DeployDockerContainersCloud & DeployPostgres+ pgvectorCloud & Deploy+ production extrasLangSmithGitHub ActionsCloudWatchStep FunctionsOpenTelemetryAWS S3AWS BedrockAWS LambdaAWS API GatewayLangSmithGitHub ActionsCloudWatchStep FunctionsOpenTelemetryAWS S3AWS BedrockAWS LambdaAWS API GatewayCapabilitiesSix capabilities that get you hired.01 / 06Architect production-grade RAG systemsHybrid retrieval (BM25 + dense embeddings) with rerankingRAGAS evaluation pipelines integrated into CIChunking strategies that survive production scale02 / 06Engineer stateful agents with LangGraphCyclical state machines with persistent checkpointersHuman-in-the-loop with proper interrupt handlingMulti-agent orchestration patterns03 / 06Build and deploy MCP serversCustom MCP servers exposing real tools to LLM clientsstdio + SSE transport implementationTool design patterns that don't break agent reasoning04 / 06Design Agentic RAG systemsCorrective and adaptive RAG patternsSelf-querying retrievers and query routingFailure modes and how production systems reco ...

# %% [markdown]
# ##Wikipedia Loader

# %%
from langchain_community.document_loaders import WikipediaLoader
loader = WikipediaLoader(query = "GEN AI" , load_max_docs=2)
docs = loader.load()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\devsa\Gen-AI\env\Lib\site-packages\requests\models.py:1116, in Response.json(self, **kwargs)
#    1115 try:
# -> 1116     return complexjson.loads(self.text, **kwargs)
#    1117 except JSONDecodeError as e:
#    1118     # Catch JSON-related errors and raise as requests.JSONDecodeError
#    1119     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[29], line 3
#       1 from langchain_community.document_loaders import WikipediaLoader
#       2 loader = WikipediaLoader(query = "GEN AI" , load_max_docs=2)
# ----> 3 docs = loader.load()
#
# File c:\Users\devsa\Gen-AI\env\Lib\site-packages\langchain_core\document_loaders\base.py:43, in BaseLoader.load(self)
#      37 def load(self) -> list[Document]:
#      38     """Load data into `Document` objects.
#      39
#      40     Returns:
#      41         The documents.
#      42     """
# ---> 43     return list(self.lazy_load())
#
# File c:\Users\devsa\Gen-AI\env\Lib\site-packages\langchain_community\document_loaders\wikipedia.py:59, in WikipediaLoader.lazy_load(self)
#      46 """
#      47 Loads the query result from Wikipedia into a list of `Document` objects.
#      48
#    (...)     51         Wikipedia pages.
#      52 """
#      53 client = WikipediaAPIWrapper(  # type: ignore[call-arg]
#      54     lang=self.lang,
#      55     top_k_results=self.load_max_docs,  # type: ignore[arg-type]
#      56     load_all_available_meta=self.load_all_available_meta,  # type: ignore[arg-type]
#      57     doc_content_chars_max=self.doc_content_chars_max,  # type: ignore[arg-type]
#      58 )
# ---> 59 yield from client.load(self.query)
#
# File c:\Users\devsa\Gen-AI\env\Lib\site-packages\langchain_community\utilities\wikipedia.py:115, in WikipediaAPIWrapper.load(self, query)
#     107 def load(self, query: str) -> List[Document]:
#     108     """
#     109     Run Wikipedia search and get the article text plus the meta information.
#     110     See
#    (...)    113
#     114     """
# --> 115     return list(self.lazy_load(query))
#
# File c:\Users\devsa\Gen-AI\env\Lib\site-packages\langchain_community\utilities\wikipedia.py:125, in WikipediaAPIWrapper.lazy_load(self, query)
#     117 def lazy_load(self, query: str) -> Iterator[Document]:
#     118     """
#     119     Run Wikipedia search and get the article text plus the meta information.
#     120     See
#    (...)    123
#     124     """
# --> 125     page_titles = self.wiki_client.search(
#     126         query[:WIKIPEDIA_MAX_QUERY_LENGTH], results=self.top_k_results
#     127     )
#     128     for page_title in page_titles[: self.top_k_results]:
#     129         if wiki_page := self._fetch_page(page_title):
#
# File c:\Users\devsa\Gen-AI\env\Lib\site-packages\wikipedia\util.py:28, in cache.__call__(self, *args, **kwargs)
#      26   ret = self._cache[key]
#      27 else:
# ---> 28   ret = self._cache[key] = self.fn(*args, **kwargs)
#      30 return ret
#
# File c:\Users\devsa\Gen-AI\env\Lib\site-packages\wikipedia\wikipedia.py:103, in search(query, results, suggestion)
#     100 if suggestion:
#     101   search_params['srinfo'] = 'suggestion'
# --> 103 raw_results = _wiki_request(search_params)
#     105 if 'error' in raw_results:
#     106   if raw_results['error']['info'] in ('HTTP request timed out.', 'Pool queue is full'):
#
# File c:\Users\devsa\Gen-AI\env\Lib\site-packages\wikipedia\wikipedia.py:742, in _wiki_request(params)
#     739 if RATE_LIMIT:
#     740   RATE_LIMIT_LAST_CALL = datetime.now()
# --> 742 return r.json()
#
# File c:\Users\devsa\Gen-AI\env\Lib\site-packages\requests\models.py:1120, in Response.json(self, **kwargs)
#    1116     return complexjson.loads(self.text, **kwargs)
#    1117 except JSONDecodeError as e:
#    1118     # Catch JSON-related errors and raise as requests.JSONDecodeError
#    1119     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# -> 1120     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
docs[0].page_content
