# %%
### langchain Model -OPenai -

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model_name="gpt-4")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from langchain_openai import ChatOpenAI
#       2 llm = ChatOpenAI(model_name="gpt-5-mini-2025-06-02")
#
# ModuleNotFoundError: No module named 'langchain_openai'

# %%
res = llm.invoke("Who is the Pm of India?")
print(res.content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 llm.invoke()
#
# NameError: name 'llm' is not defined

# %% [markdown]
# ## Starting form hereee

# %% [markdown]
# #### Connect with Google Gemini Model

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
res = llm.invoke("What is GenAI ? Explain me in short ?")

# %%
print(res.content)
# Out:
# **GenAI** stands for **Generative Artificial Intelligence**.
#
# In short, it's a type of AI that can **create new content**, such as text, images, music, or code, rather than just analyzing or classifying existing data. It learns patterns from massive datasets and uses them to generate novel outputs that are similar to, but not identical to, what it has learned.

# %% [markdown]
# #### Connect with OpenAI Model

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o")

# %%
res = llm.invoke("How to use langchain with OpenAI and Google GenAI ? Explain me in short ?")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 res = llm.invoke("How to use langchain with OpenAI and Google GenAI ? Explain me in short ?")
#
# File c:\Users\devsa\Gen-AI\env\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
# ...

# %%
print(res.content)

# %% [markdown]
# #### Connect with Anthropic Model

# %%
from langchain_anthropic import ChatAnthropic
llm = ChatAnthropic(model="claude-3.0")

# %%
res = llm.invoke("Tell me about Elon Musk in short ?")
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 res = llm.invoke("Tell me about Elon Musk in short ?")
#
# File c:\Users\devsa\Gen-AI\env\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
# ...

# %%
print(res.content)
