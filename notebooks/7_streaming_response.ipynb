# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm = ChatGoogleGenerativeAI(model = "gemini-2.5-flash", streaming = True)

# %%
question = "Can you explain GenAI?"

# %%
res = llm.stream(question)
for chunk in res:
    print(chunk.content, end = "")
# Out:
# GenAI stands for **Generative Artificial Intelligence**. It's a type of AI that can **create new, original content** across various modalities, rather than just analyzing, classifying, or predicting based on existing data.
#
# Think of it as AI that can *produce* things, like a digital artist, writer, composer, or programmer.
#
# ### How Does GenAI Work (Simplified)?
#
# 1.  **Vast Training Data:** GenAI models are trained on enormous datasets of existing content. For example:
#     *   **Text models (like ChatGPT):** Billions of pages of text from books, articles, websites, code, etc.
#     *   **Image models (like DALL-E, Midjourney):** Billions of images paired with their descriptions.
#     *   **Audio models:** Large libraries of music, speech, and sound effects.
#
# 2.  **Learning Patterns and Structures:** During training, the AI doesn't just memorize the data. It learns the underlying patterns, relationships, styles, and structures within that data.
#     *   For text, it learns grammar, syntax, common phrases, writing styles, and factual relationships between words.
#     *   For images, it learns how objects look, their textures, lighting, composition, and artistic styles.
#
# 3.  **Generation from a Prompt:** Once trained, when you give the GenAI a "prompt" (a text instruction, an image, an audio clip), it uses its learned understanding to generate something new that fits the prompt. It doesn't copy; it synthesizes and creates.
#     *   If you ask it to "write a poem about a flying cat in the style of Shakespeare," it doesn't find an existing poem. It applies its knowledge of poetry, cats, flight, and Shakespearean language to construct a new one.
#     *   If you ask it to "create an image of an astronaut riding a horse on the moon," it combines its understanding of astronauts, horses, the moon, and artistic styles to render a unique image.
#
# ### Key Characteristics of GenAI:
#
# *   **Creativity:** Its primary function is to generate novel outputs.
# *   **Contextual Understanding:** It can understand and respond to complex prompts, often grasping nuance and intent.
# *   **Multimodal (Increasingly):** While some models specialize (e.g., text-only), many are becoming multimodal, meaning they can understand and generate across different types of data (text-to-image, image-to-text, text-to-video, etc.).
# *   **Scalability:** Once trained, these models can generate content at a speed and volume impossible for humans.
#
# ### What Can GenAI Do? (Examples)
#
# *   **Text Generation:**
#     *   Writing articles, emails, marketing copy, stories, poems, scripts.
#     *   Summarizing long documents.
#     *   Translating languages.
#     *   Answering questions (Q&A).
#     *   Generating code or debugging existing code.
#     *   *Examples:* ChatGPT, Google Gemini, Anthropic Claude, Llama 2.
# *   **Image Generation:**
#     *   Creating photorealistic images or artistic illustrations from text descriptions.
#     *   Modifying existing images (e.g., changing styles, adding elements).
#     *   Generating variations of a design.
#     *   *Examples:* DALL-E, Midjourney, Stable Diffusion.
# *   **Audio Generation:**
#     *   Composing original music in various styles.
#     *   Generating realistic speech (text-to-speech) or cloning voices.
#     *   Creating sound effects.
#     *   *Examples:* Google's MusicLM, ElevenLabs.
# *   **Video Generation:**
#     *   Creating short video clips from text prompts or still images.
#     *   Animating characters or scenes.
#     *   *Examples:* RunwayML, Pika Labs.
# *   **3D Model Generation:**
#     *   Creating 3D objects or environments from text or 2D images (an emerging field).
#
# ### Why is GenAI a Big Deal?
#
# 1.  **Democratization of Creation:** It lowers the barrier for individuals and small businesses to create high-quality content that previously required specialized skills or significant resources.
# 2.  **Increased Productivity & Automation:** It can automate repetitive creative tasks, freeing up human creators for higher-level strategic work.
# 3.  **New Forms of Interaction & Experience:** It enables more dynamic and personalized user experiences, from advanced chatbots to interactive content creation tools.
# 4.  **Innovation:** It's a powerful tool for brainstorming, prototyping, and exploring new ideas across many industries.
#
# ### Challenges and Concerns:
#
# *   **Accuracy & Hallucinations:** GenAI models can sometimes generate incorrect, nonsensical, or "hallucinated" information presented as fact.
# *   **Bias:** They can perpetuate and amplify biases present in their training data, leading to unfair or discriminatory outputs.
# *   **Copyright & Intellectual Property:** Questions arise about who owns the generated content and whether training on existing copyrighted works constitutes infringement.
# *   **Misinformation & Deepfakes:** The ability to generate realistic fake content (text, images, audio, video) poses risks for misinformation and malicious use.
# *   **Job Displacement:** There are concerns about the impact on jobs in creative industries.
# *   **Environmental Impact:** Training these massive models requires significant computational power and energy.
#
# In essence, GenAI represents a significant leap in AI capabilities, shifting from analytical tasks to truly creative ones, with profound implications for technology, business, and society.

# %%
from langchain_groq import ChatGroq

# %%
llm = ChatGroq(model = "openai/gpt-oss-20b", streaming = True)

# %%
question = "Can you explain GenAI?"
res = llm.stream(question)
for chunk in res:
    print(chunk.content, end = "")
# Out:
# ## What is GenAI?
# Generative AI (GenAI) is a branch of artificial intelligence that creates new content—text, images, audio, video, code, or even 3‑D models—rather than merely recognizing or classifying existing data. Think of it as a “content‑creator” that learns patterns from a huge dataset and then produces something that *looks* like it could have come from that same dataset.
#
# ---
#
# ## 1. Core Technology
#
# | Component | What it does | Typical Example |
# |-----------|--------------|-----------------|
# | **Encoder** | Reads the input (e.g., a prompt, image, or partial sentence) and turns it into a high‑dimensional vector. | BERT, CLIP |
# | **Decoder / Generator** | Takes the encoded vector and outputs new data. | GPT‑4, DALL·E, Stable Diffusion |
# | **Self‑Attention / Transformers** | Enables the model to weigh relationships between all parts of the input, allowing it to capture long‑range dependencies. | The backbone of GPT‑4, LLaMA, etc. |
# | **Diffusion / Latent Models** | Gradually adds and removes noise to generate realistic images or audio. | Stable Diffusion, Imagen |
# | **Reinforcement Learning from Human Feedback (RLHF)** | Fine‑tunes the model to align with human preferences (e.g., safe, useful, non‑biased). | GPT‑4’s policy tuning |
#
# ---
#
# ## 2. How It Works (Simplified)
#
# 1. **Data Collection**
#    - Gather millions/billions of examples (books, web pages, images, videos, code, etc.).
#    - Preprocess: tokenize text, normalize images, etc.
#
# 2. **Pre‑training**
#    - Train a massive neural net to predict the next token, reconstruct missing parts, or denoise data.
#    - The objective is to capture the statistical regularities of the data.
#
# 3. **Fine‑tuning / Prompting**
#    - Adapt the pre‑trained model to a specific domain or task (e.g., medical diagnosis, legal drafting).
#    - Or simply provide a prompt (e.g., “Write a poem about the sea”) and let the model generate.
#
# 4. **Generation**
#    - Sample from the model’s probability distribution.
#    - Techniques: greedy decoding, beam search, nucleus sampling, temperature control, etc.
#
# 5. **Post‑processing & Safety**
#    - Filter out toxic or copyrighted content.
#    - Apply RLHF or policy models to align with user intent.
#
# ---
#
# ## 3. Key Generative Models
#
# | Model | Domain | Year | Notable Features |
# |-------|--------|------|------------------|
# | **GPT‑3 / GPT‑4** | Text | 2020 / 2023 | 175B / 100B parameters; few‑shot learning; versatile. |
# | **ChatGPT** | Conversational AI | 2022 | Fine‑tuned GPT‑3.5 with RLHF. |
# | **DALL·E / DALL·E 2 / Imagen** | Text‑to‑Image | 2021–2022 | Generates high‑resolution images from prompts. |
# | **Stable Diffusion** | Text‑to‑Image | 2022 | Open‑source diffusion model; latent space. |
# | **Midjourney** | Text‑to‑Image | 2022 | Community‑driven, artistic style. |
# | **Codex** | Code | 2021 | Generates code from natural language. |
# | **AudioGen / Jukebox** | Music | 2020–2021 | Generates music or voice. |
# | **VideoGen** | Video | 2023 | Generates short video clips from prompts. |
#
# ---
#
# ## 4. Applications
#
# | Field | Use‑Case | Example |
# |-------|----------|---------|
# | **Content Creation** | Articles, blogs, social media posts | AI‑written news articles, marketing copy |
# | **Design** | Logos, UI mockups, 3‑D assets | AI‑generated product prototypes |
# | **Art & Entertainment** | Digital art, music, game assets | AI‑composed songs, NPC dialogues |
# | **Education** | Tutoring, study aids | AI‑generated flashcards, explanations |
# | **Healthcare** | Medical imaging, drug discovery | Generating synthetic patient data |
# | **Software Development** | Code generation, bug fixes | GitHub Copilot, auto‑completion |
# | **Business** | Reports, proposals, customer support | AI‑written financial reports, chatbots |
#
# ---
#
# ## 5. Advantages
#
# - **Speed & Scale**: Produce content in seconds that would take humans hours/days.
# - **Cost‑Efficiency**: Reduce labor costs for repetitive tasks.
# - **Personalization**: Tailor content to individual preferences at scale.
# - **Accessibility**: Help people with disabilities (e.g., generating captions, describing images).
#
# ---
#
# ## 6. Challenges & Risks
#
# | Issue | Why it matters | Mitigation |
# |-------|----------------|------------|
# | **Bias & Fairness** | Models reflect training data biases. | Diverse datasets, bias audits, debiasing algorithms. |
# | **Hallucinations** | Generates plausible but false information. | Post‑generation verification, factuality checks. |
# | **Copyright & Plagiarism** | May reproduce copyrighted text or images. | Copyright filtering, licensing checks. |
# | **Misuse** | Deepfakes, fake news, phishing. | Content moderation, watermarking, policy controls. |
# | **Energy & Compute** | Training large models is energy‑intensive. | Efficient architectures, distillation, renewable energy. |
# | **Explainability** | Hard to trace why a model produced something. | Model introspection tools, transparency reports. |
# | **Privacy** | Could inadvertently leak personal data. | Differential privacy, data minimization. |
#
# ---
#
# ## 7. Ethical & Governance Considerations
#
# | Principle | Practical Steps |
# |-----------|-----------------|
# | **Transparency** | Publish model cards, training data summaries. |
# | **Accountability** | Define clear responsibility for outputs. |
# | **User Control** | Allow users to edit or delete AI‑generated content. |
# | **Inclusivity** | Engage diverse communities in model development. |
# | **Safety** | Implement content filters, safe‑harboring guidelines. |
#
# ---
#
# ## 8. Future Outlook
#
# | Trend | What it Means |
# |-------|---------------|
# | **Multimodal Models** | Combine text, image, audio, video in one model (e.g., GPT‑4 multimodal, LLaVA). |
# | **Edge Deployment** | Smaller, efficient models running on phones or IoT devices. |
# | **Adaptive Personalization** | Models that learn from a user’s feedback in real time. |
# | **Regulatory Landscape** | Governments drafting AI‑specific regulations (e.g., EU AI Act). |
# | **Human‑in‑the‑Loop** | Hybrid systems where humans curate or refine AI outputs. |
#
# ---
#
# ## Quick Takeaway
#
# - **GenAI** = AI that *creates* new content, not just analyzes it.
# - It relies on large transformer or diffusion models trained on massive datasets.
# - It powers everything from chatbots to music composition, but brings risks like bias, hallucinations, and misuse.
# - Responsible deployment requires transparency, safety checks, and ongoing human oversight.
#
# ---
#
# ### Want to dive deeper?
# - **Read the original papers**: *Attention is All You Need*, *DALL·E*, *Stable Diffusion*.
# - **Explore open‑source implementations**: Hugging Face Transformers, Diffusers.
# - **Experiment**: Play with ChatGPT, DALL·E, or run a local GPT‑2 model on your laptop.
#
# Happy exploring!
